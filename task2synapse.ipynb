# %% [markdown]
# ## This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# import matplotlib.pyplot as plt
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/kaggle/input/ge-2024-results1/GE_2024_Results.csv')
df
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...    ...                        ...                        ...
# 8901  8899                West Bengal                   Uluberia
# 8902  8900                West Bengal                   Uluberia
# 8903  8904  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8904  8901                West Bengal                   Uluberia
# 8905  8902                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# ...

# %%
df.shape #to find dimensions
# Out:
# (8906, 10)

# %%
df.head(20) #first 20 rows
# Out:
#     ID                      State               Constituency  \
# 0    1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1    2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2    3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 5    5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 6    6  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 7    7  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8    8  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 10   9  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 11  10  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 12  11  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13  12  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...

# %%
df = df.drop(columns = ['ID'])
df
# Out:
#                           State               Constituency  \
# 0     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...                         ...                        ...
# 8901                West Bengal                   Uluberia
# 8902                West Bengal                   Uluberia
# 8903  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8904                West Bengal                   Uluberia
# 8905                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# ...

# %%
df = df.sort_index(axis = 0)
df
# Out:
#                           State               Constituency  \
# 0     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...                         ...                        ...
# 8901                West Bengal                   Uluberia
# 8902                West Bengal                   Uluberia
# 8903  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8904                West Bengal                   Uluberia
# 8905                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# ...

# %%
df = df.dropna()
df
# Out:
#                           State               Constituency  \
# 0     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 5     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...                         ...                        ...
# 8900                West Bengal                   Uluberia
# 8901                West Bengal                   Uluberia
# 8902                West Bengal                   Uluberia
# 8904                West Bengal                   Uluberia
# 8905                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# ...

# %%
df.loc[df["State"]=="Telangana"]["Total Votes"].sort_values(ascending=False).head(5)
# Out:
# 7052    991042.0
# 6856    809882.0
# 7140    784337.0
# 6960    766929.0
# 6900    661981.0
# Name: Total Votes, dtype: float64

# %%
a = df.groupby("State")["Total Votes"].sum()

# %%
df['Total Votes'].sum()
# Out:
# 645363445.0

# %%
df.groupby("State")["Total Votes"].sum()/df['Total Votes'].sum()*100
# Out:
# State
# Andaman & Nicobar Islands                0.031380
# Andhra Pradesh                           5.226410
# Arunachal Pradesh                        0.112068
# Assam                                    3.108306
# Bihar                                    6.732478
# Chandigarh                               0.069616
# Chhattisgarh                             2.333778
# Dadra & Nagar Haveli and Daman & Diu     0.046175
# Goa                                      0.140469
# Gujarat                                  4.511504
# Haryana                                  2.022980
# Himachal Pradesh                         0.630638
# Jammu and Kashmir                        0.798185
# Jharkhand                                2.671670
# Karnataka                                6.011127
# Kerala                                   3.095997
# Ladakh                                   0.021000
# Lakshadweep                              0.007624
# Madhya Pradesh                           5.878897
# ...

# %%
df.groupby("Party")["Total Votes"].sum().sort_values(ascending=False).head(5)
# Out:
# Party
# Bharatiya Janata Party          235973935.0
# Indian National Congress        136759064.0
# Samajwadi Party                  29549381.0
# All India Trinamool Congress     28213393.0
# Independent                      17844442.0
# Name: Total Votes, dtype: float64

# %%
candidatesLost = df.loc[df["Result"] == "Lost"]
candidatesLost['% of Votes'] = candidatesLost['% of Votes'].astype(float)
candidatesLost.sort_values(by = '% of Votes',ascending=False).head(10)
# Out:
# /tmp/ipykernel_33/3850207045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   candidatesLost['% of Votes'] = candidatesLost['% of Votes'].astype(float)
#               State       Constituency                  Candidate  \
# 5646      Rajasthan       JAIPUR RURAL                ANIL CHOPRA
# 5683      Rajasthan          JHUNJHUNU       SHUBHKARAN CHOUDHARY
# 2723      Karnataka           Gulbarga         DR. UMESH G JADHAV
# 1206     Chandigarh         Chandigarh              SANJAY TANDON
# 3824    Maharashtra              Dhule      BHAMRE SUBHASH RAMRAO
# 2440      Karnataka  Bangalore central           MANSOOR ALI KHAN
# 7923  Uttar Pradesh             Kanpur                 ALOK MISRA
# ...

# %%
candidatesWon = df.loc[df["Result"] == "Won"]
candidatesWon = candidatesWon.sort_values(by="% of Votes", ascending=False).head(5)
candidatesWon
# Out:
#                State  Constituency              Candidate  \
# 3292  Madhya Pradesh        INDORE        SHANKAR LALWANI
# 1667         Gujarat       Navsari              C R PATIL
# 3525  Madhya Pradesh       VIDISHA  SHIVRAJ SINGH CHOUHAN
# 1593         Gujarat   Gandhinagar              AMIT SHAH
# 7355         Tripura  Tripura West       BIPLAB KUMAR DEB
#
#                        Party EVM Votes Postal Votes  Total Votes % of Votes  \
# 3292  Bharatiya Janata Party   1223746         3005    1226751.0      78.54
# 1667  Bharatiya Janata Party   1023366         7699    1031065.0      77.05
# 3525  Bharatiya Janata Party   1111556         4904    1116460.0       76.7
# 1593  Bharatiya Janata Party    999984        10988    1010972.0      76.48
# 7355  Bharatiya Janata Party    868484        12857     881341.0      72.85
#
#      Result
# 3292    Won
# 1667    Won
# 3525    Won
# 1593    Won
# 7355    Won

# %%
Candid5 = df.loc[df["Result"] == "Won"]
Candid5 = Candid5.sort_values(by="% of Votes", ascending=False).head(5)
labels = Candid5['Candidate'].unique()
values = Candid5['Total Votes'].unique()
plt.pie(values, labels = labels,
        #autopct = '%1.1f%%' for adding the % value for each element. Refer to documentation to confirm
        autopct = '%1.1f%%',
        wedgeprops = {'edgecolor': 'black'})
plt.title('Top 5 Candidates')
plt.tight_layout()
plt.show()

# %%
# barG = df.loc[df['State'] == 'Karnataka']
parties = barG['Party'].unique()
barG.loc[:,'Postal Votes'] = barG['Postal Votes'].replace('-','0')
barG.loc[:,'Postal Votes'] = barG['Postal Votes'].astype(float)
votes = []
for i in parties:
     votes.append(barG.loc[df['Party'] == i, 'Postal Votes'].sum())

fig, ax = plt.subplots(figsize=(150,50))
plt.bar(parties, votes)
plt.yscale('log')
plt.xlabel('Parties', fontsize=86, fontweight='bold', color = '#ff0000')
plt.ylabel('Votes', fontsize=86, fontweight='bold', color = '#167823')
plt.title('Postal Votes received by the parties in Karnataka',loc = 'left', fontsize=116, fontweight='bold')
plt.tight_layout()
plt.show()
